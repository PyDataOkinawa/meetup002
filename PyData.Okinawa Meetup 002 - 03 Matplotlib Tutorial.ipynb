# %% [markdown]
# # Matplotlib Tutorial

# %% [markdown]
# # Matplotlib とは
#
# - Pythonのグラフ描画ライブラリ（de facto standard）
# - ２次元プロット、３次元プロット、インタラクティブな描画、アニメーションなどなど
# - 大体の描画はこれでできる

# %%
from IPython.display import IFrame
IFrame("http://matplotlib.org/", width="100%", height="400")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="http://matplotlib.org/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# - [Matplotlib Official HP](http://matplotlib.org/)：オフィシャルページ
# - [Gallery](http://matplotlib.org/gallery.html)：まずギャラリーを見てイメージをつかむ
# - [Examples](http://matplotlib.org/examples/index.html)：豊富なコードの例。コードがメイン
# - [pyplot](http://matplotlib.org/api/pyplot_summary.html)：ほとんどの描画はmaptlotlib.pyplotで事足りる
# - [Screenshots](http://matplotlib.org/users/screenshots.html) ：いくつかの代表的な例

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
import numpy as np

N = 5
menMeans   = (20, 35, 30, 35, 27)
womenMeans = (25, 32, 34, 20, 25)
menStd     = (2, 3, 4, 1, 2)
womenStd   = (3, 5, 2, 3, 3)
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, menMeans,   width, color='b', yerr=womenStd)
p2 = plt.bar(ind, womenMeans, width, color='y',
             bottom=menMeans, yerr=menStd)

plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.xticks(ind+width/2., ('G1', 'G2', 'G3', 'G4', 'G5') )
plt.yticks(np.arange(0,81,10))
plt.legend( (p1[0], p2[0]), ('Men', 'Women') )

plt.show()

# %%
plt.hist(np.random.randn(100), orientation='horizontal', color='red');

# %% [markdown]
# ## やること
#
# - plots, histograms, power spectra, bar charts, errorcharts, scatterplots, etc,

# %%
x = np.arange(10, 20, 0.5)

# %%
y = np.sin(x)

# %%
plt.plot(y, 'r+')

# %%
saved_state = mpl.rcParams.copy()

# %%
from seaborn import load_dataset
iris = load_dataset("iris")

# %%
mpl.rcParams.update(saved_state)

# %%
font = {'family' : 'osaka',
        'size'   : 22}
mpl.rc('font', **font)

# %%
iris.plot()
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
plt.plot(iris.petal_length)

# %%
plt.hist(iris.petal_length);

# %%
mgr = plt.xkcd()

# %%
plt.hist(iris.petal_length);

# %%
mpl.rcParams.update(saved_state)

# %%
plt.hist(iris.petal_length);

# %%
plt.style.available
# Out:
# [u'dark_background', u'bmh', u'grayscale', u'ggplot', u'fivethirtyeight']

# %%
for s in plt.style.available:
    plt.style.use(s)
    plt.figure()
    plt.hist(iris.petal_length)
    plt.title(s)

# %%
mpl.rcParams.update(saved_state)
plt.hist(iris.petal_length);
